# %%
#installs, only use what you need

#conda install bokeh
#pip install decorator==5.0.9

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
# prepare the data
adjacency_matrix = np.genfromtxt('adjacency_matrix.csv', delimiter=',')
G = nx.from_numpy_matrix(adjacency_matrix)

# %%
# prepare the data
adjacency_matrix = np.genfromtxt('adjacency_matrix.csv', delimiter=',')
G = nx.from_numpy_matrix(adjacency_matrix)

# overall plot size
fig = plt.figure(figsize=(15,15))

pos=nx.spring_layout(G)

# node and font size so it's legible
nx.draw_networkx(G, pos, node_size=900, font_size=20)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {(0, 2): Text(0.14834941075421684, -0.18362326916255092, '1.0'),
#  (0, 9): Text(0.3745886286055543, -0.35325223777972914, '3.0'),
#  (0, 11): Text(0.009893863141359593, -0.12909065372369544, '1.0'),
#  (0, 15): Text(0.2531077097373587, -0.3547503726910781, '1.0'),
#  (0, 1): Text(-0.1960407202622984, -0.21856231421712222, '1.0'),
#  (0, 8): Text(-0.10480442399228479, -0.29104271429422474, '3.0'),
#  (0, 18): Text(0.21399843353860984, -0.6536067044064129, '1.0'),
#  (0, 22): Text(0.024963551538164874, -0.28752286216396306, '4.0'),
#  (0, 24): Text(-0.07238161463482487, -0.1827614966524264, '4.0'),
#  (1, 4): Text(-0.6642287916033601, 0.06975322214973691, '2.0'),
#  (1, 5): Text(0.04056784207799699, 0.029201243890076573, '1.0'),
#  (1, 7): Text(-0.46844822329033775, 0.11091619345853435, '9.0'),
#  (1, 13): Text(-0.20575795896970642, -0.3638911113026084, '2.0'),
#  (1, 22): Text(-0.24947204447328297, -0.11517790341386432, '2.0'),
# ...

# %%
# prepare the data
adjacency_matrix = np.genfromtxt('adjacency_matrix.csv', delimiter=',')
G = nx.from_numpy_matrix(adjacency_matrix)

# overall plot size
fig = plt.figure(figsize=(15,15))

pos=nx.spring_layout(G) 

# node and font size so it's legible
# made green color
nx.draw_networkx(G, pos, node_size=900, font_size=15, node_color='#2ea64e')
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {(0, 2): Text(-0.28675566459422624, 0.019000682296368365, '1.0'),
#  (0, 9): Text(-0.3227265414927033, -0.5874936413497023, '3.0'),
#  (0, 11): Text(0.010905838965556275, -0.07057683061431416, '1.0'),
#  (0, 15): Text(-0.29913048211567206, -0.46637188100656257, '1.0'),
#  (0, 1): Text(-0.10806186359999112, 0.04529989045463256, '1.0'),
#  (0, 8): Text(-0.18257401077110705, -0.39309481709254174, '3.0'),
#  (0, 18): Text(-0.6724563483126068, -0.4131402170649641, '1.0'),
#  (0, 22): Text(-0.14987884696831702, -0.11934694474825998, '4.0'),
#  (0, 24): Text(-0.34489325189087905, -0.15906349283457816, '4.0'),
#  (1, 4): Text(-0.04118919206409062, 0.6345369451137535, '2.0'),
#  (1, 5): Text(0.5307856232961394, 0.11876142746899918, '1.0'),
#  (1, 7): Text(0.3203877354502358, 0.46492862291691583, '9.0'),
#  (1, 13): Text(-0.3097453535365539, 0.1313857076652301, '2.0'),
#  (1, 22): Text(0.08697198605690554, 0.24960883654047777, '2.0'),
# ...

# %%
# prepare the data
adjacency_matrix = np.genfromtxt('adjacency_matrix.csv', delimiter=',')
G = nx.from_numpy_matrix(adjacency_matrix)

# overall plot size
fig = plt.figure(figsize=(15,15))

pos=nx.spring_layout(G) 

# node and font size so it's legible
# made orange color
# changed edges to be dashed instead of solid
nx.draw_networkx(G, pos, node_size=900, font_size=15, node_color='#fea64e', style='--')
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {(0, 2): Text(0.23509623328219614, -0.04576831631325817, '1.0'),
#  (0, 9): Text(0.42657310600075937, -0.3509739917670485, '3.0'),
#  (0, 11): Text(-0.03688858558902919, -0.1622016323548938, '1.0'),
#  (0, 15): Text(0.3168561289630103, -0.351773126499267, '1.0'),
#  (0, 1): Text(-0.05987727968923362, -0.06503441848244705, '1.0'),
#  (0, 8): Text(0.35500173273753743, 0.04352703663024064, '3.0'),
#  (0, 18): Text(0.5605529720900435, -0.31557185927958586, '1.0'),
#  (0, 22): Text(0.10194517494677693, -0.26819644540914683, '4.0'),
#  (0, 24): Text(0.14937745204442202, 0.0039059884151384505, '4.0'),
#  (1, 4): Text(-0.6225772439428408, 0.18093195776551496, '2.0'),
#  (1, 5): Text(-0.47976151498405817, -0.3185756570964927, '1.0'),
#  (1, 7): Text(-0.4826669877867543, 0.18083831166083583, '9.0'),
#  (1, 13): Text(0.05470928824678403, 0.008157222919986967, '2.0'),
#  (1, 22): Text(-0.23269444473825265, -0.12273821732128057, '2.0'),
# ...

# %%
# prepare the data
adjacency_matrix = np.genfromtxt('adjacency_matrix.csv', delimiter=',')
G = nx.from_numpy_matrix(adjacency_matrix)

# overall plot size
# made smaller -- this doesn't look so good
fig = plt.figure(figsize=(10,10))

pos=nx.spring_layout(G) 

# node and font size so it's legible
# made orange color
# changed edges to be dashed instead of solid
nx.draw_networkx(G, pos, node_size=800, font_size=14, node_color='#fea64e', style='--')
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {(0, 2): Text(0.3934057158903528, -0.18387793310657188, '1.0'),
#  (0, 9): Text(0.16323501225190482, -0.24707289171859595, '3.0'),
#  (0, 11): Text(-0.14110347502230172, 0.08196915049765224, '1.0'),
#  (0, 15): Text(0.2515603983765552, -0.2119198277077765, '1.0'),
#  (0, 1): Text(-0.009725667005175936, -0.09224422914641162, '1.0'),
#  (0, 8): Text(0.4886167271150518, -0.08872787706467256, '3.0'),
#  (0, 18): Text(0.33156433257536677, -0.5070424507983746, '1.0'),
#  (0, 22): Text(0.12943858182941168, 0.030189606982262127, '4.0'),
#  (0, 24): Text(0.20906957556641034, -0.03774368103750299, '4.0'),
#  (1, 4): Text(-0.4839710076630947, -0.14355315547572967, '2.0'),
#  (1, 5): Text(-0.6638920228696352, -0.01755313756505851, '1.0'),
#  (1, 7): Text(-0.30023539186949866, 0.13027597528566182, '9.0'),
#  (1, 13): Text(-0.1507846479531563, -0.4291611874799445, '2.0'),
#  (1, 22): Text(-0.18861979690468272, 0.052656321974413375, '2.0'),
# ...

# %%
# prepare the data
adjacency_matrix = np.genfromtxt('adjacency_matrix.csv', delimiter=',')
G = nx.from_numpy_matrix(adjacency_matrix)

# overall plot size
# made smaller -- this doesn't look so good
fig = plt.figure(figsize=(15,15))

pos=nx.spring_layout(G) 

# node and font size so it's legible
# made black nodes and white font
# changed edges to be tightly dashed instead of solid
nx.draw_networkx(G, pos, node_size=800, font_size=16, font_color='#ffffff', node_color='#000000', style=':')
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {(0, 2): Text(0.33808008067249024, -0.30479348179880095, '1.0'),
#  (0, 9): Text(0.3843366492910235, -0.14528072564982872, '3.0'),
#  (0, 11): Text(-0.21701166087649162, 0.18266777629323608, '1.0'),
#  (0, 15): Text(0.27447818882854585, -0.2081424798061959, '1.0'),
#  (0, 1): Text(-0.12431742728108561, 0.1462250666213957, '1.0'),
#  (0, 8): Text(0.4572663213844613, 0.1603315643191579, '3.0'),
#  (0, 18): Text(0.05148539500040916, -0.2864136685349253, '1.0'),
#  (0, 22): Text(0.04202863326202701, -0.12477537432165181, '4.0'),
#  (0, 24): Text(0.18289523952082662, 0.22279785839924304, '4.0'),
#  (1, 4): Text(-0.5716681154596741, 0.553361082020321, '2.0'),
#  (1, 5): Text(-0.755674772082032, -0.051453587175626564, '1.0'),
#  (1, 7): Text(-0.3800660160818513, 0.27950598116219794, '9.0'),
#  (1, 13): Text(-0.2979040434734147, 0.07138781680745726, '2.0'),
#  (1, 22): Text(-0.34500348362095146, -0.019063357197271397, '2.0'),
# ...
